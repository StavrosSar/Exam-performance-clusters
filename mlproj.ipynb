# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import os
import warnings

# %%
# Load the dataset
url = "2012_SAT_Results.csv"
data = pd.read_csv(url)

# Remove rows with "s" values in the specified columns
data = data[~data['Num of SAT Test Takers'].str.contains('s', na=False)]
data = data[~data['SAT Critical Reading Avg. Score'].str.contains('s', na=False)]
data = data[~data['SAT Math Avg. Score'].str.contains('s', na=False)]
data = data[~data['SAT Writing Avg. Score'].str.contains('s', na=False)]

# Set environment variable to avoid memory leak warning
os.environ["OMP_NUM_THREADS"] = "2"

# Suppress FutureWarning related to use_inf_as_na
warnings.filterwarnings("ignore", message="use_inf_as_na option is deprecated")

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# 2                    370
# 3                    359
# 4                    384

# %%
print("Summary Statistics:")
print(data.describe())
# Out:
# Summary Statistics:
#            DBN                                    SCHOOL NAME  \
# count      421                                            421
# unique     421                                            421
# top     01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# freq         1                                              1
#
#        Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# count                     421                             421
# unique                    174                             163
# top                        54                             398
# freq                       10                               8
#
#        SAT Math Avg. Score SAT Writing Avg. Score
# count                  421                    421
# unique                 172                    162
# top                    385                    370
# freq                     9                      9

# %% [markdown]
# **PLOT THE CSV**

# %%
features = ['Num of SAT Test Takers', 'SAT Critical Reading Avg. Score', 'SAT Math Avg. Score', 'SAT Writing Avg. Score']
colors = ['orange', 'salmon', 'lightgreen', 'skyblue']
titles = ['Distribution of Number of Students', 'Distribution of Reading Scores', 'Distribution of Maths Scores', 'Distribution of Writing Scores']
xlabels = ['Number of Students', 'Reading Score', 'Maths Score', 'Writing Score']

for feature, color, title, xlabel in zip(features, colors, titles, xlabels):
    plt.figure(figsize=(40, 20))
    ax = sns.histplot(data[feature], kde=True, bins=30, color=color)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Frequency')
    plt.xticks(rotation=90)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.xlim(left=0)
    plt.show()

# %% [markdown]
# **PCA**

# %%
# Select features for clustering
features = data[['SAT Critical Reading Avg. Score', 'SAT Math Avg. Score', 'SAT Writing Avg. Score']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Dimensionality Reduction: Apply PCA
pca = PCA(n_components=2)  # Reduce to 2 components for visualization
pca_features = pca.fit_transform(scaled_features)

# %% [markdown]
# **Kmeans BELOW**

# %%
# Clustering: KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_features)

# Add cluster labels to the dataset
data['Cluster'] = clusters

# Get unique cluster labels
unique_clusters = np.unique(clusters)

# Define colors for each cluster
cluster_colors = {cluster: color for cluster, color in zip(unique_clusters, ['tab:blue', 'tab:orange', 'tab:green'])}

# Visualization: Plot clusters in reduced dimensionality space
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_features[:, 0], y=pca_features[:, 1], hue=data['Cluster'], palette=cluster_colors, legend='full')
plt.title('Clustering of Schools based on Exam Performance')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# C:\Users\stavros\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# Count the number of schools in each cluster
cluster_counts = data['Cluster'].value_counts()

# Sort the cluster counts from smallest to largest
cluster_counts = cluster_counts.sort_index()

# Create a bar plot showing the number of schools in each cluster
plt.figure(figsize=(8, 6))
barplot = sns.barplot(x=cluster_counts.index, y=cluster_counts.values, palette='viridis')

# Annotate each bar with its value
for i, count in enumerate(cluster_counts):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=10)

plt.title('Number of Schools in Each Cluster')
plt.xlabel('Clusters')
plt.ylabel('Number of Schools')

# Set correct cluster labels
barplot.set_xticklabels(['Cluster 0', 'Cluster 1', 'Cluster 2'])

plt.show()
# Out:
# C:\Users\stavros\AppData\Local\Temp\ipykernel_14456\332179589.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=cluster_counts.index, y=cluster_counts.values, palette='viridis')
# C:\Users\stavros\AppData\Local\Temp\ipykernel_14456\332179589.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   barplot.set_xticklabels(['Cluster 0', 'Cluster 1', 'Cluster 2'])

# %%
# Iterate over each cluster
for cluster_num in range(3):
    cluster_schools = data[data['Cluster'] == cluster_num]['SCHOOL NAME']# Get the schools in the current cluster
    print(f"Cluster {cluster_num}:")# Print the cluster number
    
    # Print each school in the cluster
    for i, school in enumerate(cluster_schools, start=1):
        print(f"{i}. {school}")

    print()
# Out:
# Cluster 0:
# 1. CASCADES HIGH SCHOOL
# 2. PACE HIGH SCHOOL
# 3. URBAN ASSEMBLY SCHOOL OF DESIGN AND CONSTRUCTION, THE
# 4. NYC ISCHOOL
# 5. HIGH SCHOOL FOR ENVIRONMENTAL STUDIES
# 6. INSTITUTE FOR COLLABORATIVE EDUCATION
# 7. PROFESSIONAL PERFORMING ARTS HIGH SCHOOL
# 8. N.Y.C. MUSEUM SCHOOL
# 9. HIGH SCHOOL FOR HEALTH PROFESSIONS AND HUMAN SERVICES
# 10. LEADERSHIP AND PUBLIC SERVICE HIGH SCHOOL
# 11. MANHATTAN VILLAGE ACADEMY
# 12. HIGH SCHOOL OF ECONOMICS AND FINANCE
# 13. TALENT UNLIMITED HIGH SCHOOL
# 14. MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 15. JACQUELINE KENNEDY ONASSIS HIGH SCHOOL
# 16. REPERTORY COMPANY HIGH SCHOOL FOR THEATRE ARTS
# 17. HIGH SCHOOL FOR DUAL LANGUAGE AND ASIAN STUDIES
# 18. HIGH SCHOOL M560 s CITY AS SCHOOL
# 19. HARVEY MILK HIGH SCHOOL
# 20. THE HIGH SCHOOL OF FASHION INDUSTRIES
# 21. HUMANITIES PREPARATORY ACADEMY
# 22. ART AND DESIGN HIGH SCHOOL
# 23. LIFE SCIENCES SECONDARY SCHOOL
# 24. HIGH SCHOOL OF ARTS AND TECHNOLOGY
# 25. MANHATTAN / HUNTER SCIENCE HIGH SCHOOL
# 26. MANHATTAN CENTER FOR SCIENCE AND MATHEMATICS
# 27. YOUNG WOMEN'S LEADERSHIP SCHOOL
# 28. FREDERICK DOUGLASS ACADEMY
# 29. CITY COLLEGE ACADEMY OF THE ARTS
# 30. A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL
# 31. HOSTOSsLINCOLN ACADEMY OF SCIENCE
# 32. HERBERT H. LEHMAN HIGH SCHOOL
# 33. URBAN ASSEMBLY SCHOOL FOR APPLIED MATH AND SCIENCE, THE
# 34. BRONX CENTER FOR SCIENCE AND MATHEMATICS
# 35. RIVERDALE / KINGSBRIDGE ACADEMY (MIDDLE SCHOOL / HIGH SCHOOL 141)
# 36. DEWITT CLINTON HIGH SCHOOL
# 37. CELIA CRUZ BRONX HIGH SCHOOL OF MUSIC, THE
# 38. MARBLE HILL HIGH SCHOOL FOR INTERNATIONAL STUDIES
# 39. COLLEGIATE INSTITUTE FOR MATH AND SCIENCE
# 40. BRONX HIGH SCHOOL FOR THE VISUAL ARTS
# 41. PELHAM PREPARATORY ACADEMY
# 42. BRONX LATIN
# 43. ACADEMY OF BUSINESS AND COMMUNITY DEVELOPMENT
# 44. BEDFORD ACADEMY HIGH SCHOOL
# 45. BENJAMIN BANNEKER ACADEMY
# 46. CITY POLYTECHNIC HIGH SCHOOL OF ENGINEERING, ARCHITECTURE, AND TECHNOLOGY
# 47. BROOKLYN HIGH SCHOOL OF THE ARTS
# 48. SOUTH BROOKLYN COMMUNITY HIGH SCHOOL
# 49. SCIENCE, TECHNOLOGY AND RESEARCH EARLY COLLEGE HIGH SCHOOL AT ERASMUS
# 50. HIGH SCHOOL FOR PUBLIC SERVICE: HEROES OF TOMORROW
# 51. MEDGAR EVERS COLLEGE PREPARATORY SCHOOL
# 52. CLARA BARTON HIGH SCHOOL
# 53. EAST NEW YORK FAMILY ACADEMY
# 54. NEW UTRECHT HIGH SCHOOL
# 55. HIGH SCHOOL OF TELECOMMUNICATION ARTS AND TECHNOLOGY
# 56. FORT HAMILTON HIGH SCHOOL
# 57. FRANKLIN DELANO ROOSEVELT HIGH SCHOOL
# 58. RACHEL CARSON HIGH SCHOOL FOR COASTAL STUDIES
# 59. EDWARD R. MURROW HIGH SCHOOL
# 60. JOHN DEWEY HIGH SCHOOL
# 61. BROOKLYN STUDIO SECONDARY SCHOOL
# 62. MIDWOOD HIGH SCHOOL
# 63. JAMES MADISON HIGH SCHOOL
# 64. BROOKLYN COLLEGE ACADEMY
# 65. ACADEMY OF FINANCE AND ENTERPRISE
# 66. CIVIC LEADERSHIP ACADEMY
# 67. ROBERT F. WAGNER, JR. SECONDARY SCHOOL FOR ARTS AND TECHNOLOGY
# 68. QUEENS VOCATIONAL AND TECHNICAL HIGH SCHOOL
# 69. AVIATION CAREER & TECHNICAL EDUCATION HIGH SCHOOL
# 70. QUEENS SCHOOL OF INQUIRY, THE
# 71. EASTsWEST SCHOOL OF INTERNATIONAL STUDIES
# 72. WORLD JOURNALISM PREPARATORY: A COLLEGE BOARD SCHOOL
# 73. JOHN BOWNE HIGH SCHOOL
# 74. ROBERT F. KENNEDY COMMUNITY HIGH SCHOOL
# 75. BENJAMIN N. CARDOZO HIGH SCHOOL
# 76. FRANCIS LEWIS HIGH SCHOOL
# 77. BAYSIDE HIGH SCHOOL
# 78. QUEENS HIGH SCHOOL OF TEACHING, LIBERAL ARTS AND THE SCIENCES
# 79. CHANNEL VIEW SCHOOL FOR RESEARCH
# 80. ROBERT H. GODDARD HIGH SCHOOL OF COMMUNICATION ARTS AND TECHNOLOGY
# 81. SCHOLARS' ACADEMY
# 82. HIGH SCHOOL FOR CONSTRUCTION TRADES, ENGINEERING AND ARCHITECTURE
# 83. QUEENS COLLEGIATE: A COLLEGE BOARD SCHOOL
# 84. JAMAICA GATEWAY TO THE SCIENCES
# 85. FOREST HILLS HIGH SCHOOL
# 86. THOMAS A. EDISON CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 87. QUEENS GATEWAY TO HEALTH SCIENCES SECONDARY SCHOOL
# 88. YOUNG WOMEN'S LEADERSHIP SCHOOL, QUEENS
# 89. GEORGE WASHINGTON CARVER HIGH SCHOOL FOR THE SCIENCES
# 90. ACADEMY FOR CAREERS IN TELEVISION AND FILM
# 91. WILLIAM CULLEN BRYANT HIGH SCHOOL
# 92. FRANK SINATRA SCHOOL OF THE ARTS HIGH SCHOOL
# 93. INFORMATION TECHNOLOGY HIGH SCHOOL
# 94. ACADEMY OF AMERICAN STUDIES
# 95. CSI HIGH SCHOOL FOR INTERNATIONAL STUDIES
# 96. THE MICHAEL J. PETRIDES SCHOOL
# 97. NEW DORP HIGH SCHOOL
# 98. PORT RICHMOND HIGH SCHOOL
# 99. CURTIS HIGH SCHOOL
# 100. TOTTENVILLE HIGH SCHOOL
# 101. SUSAN E. WAGNER HIGH SCHOOL
# 102. CONCORD HIGH SCHOOL
# 103. RALPH R. MCKEE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 104. ALL CITY LEADERSHIP SECONDARY SCHOOL
# 105. P.S. Q811
# 106. GED PLUS s CITYWIDE
#
# Cluster 1:
# 1. HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 2. UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 3. EAST SIDE COMMUNITY SCHOOL
# 4. FORSYTH SATELLITE ACADEMY
# 5. MARTA VALLE HIGH SCHOOL
# 6. LOWER EAST SIDE PREPARATORY HIGH SCHOOL
# 7. 47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL
# 8. FOOD AND FINANCE HIGH SCHOOL
# 9. ESSEX STREET ACADEMY
# 10. HIGH SCHOOL OF HOSPITALITY MANAGEMENT
# 11. FACING HISTORY SCHOOL, THE
# 12. URBAN ASSEMBLY ACADEMY OF GOVERNMENT AND LAW, THE
# 13. LOWER MANHATTAN ARTS ACADEMY
# 14. JAMES BALDWIN SCHOOL, THE: A SCHOOL FOR EXPEDITIONARY LEARNING
# 15. URBAN ASSEMBLY SCHOOL OF BUSINESS FOR YOUNG WOMEN, THE
# 16. GRAMERCY ARTS HIGH SCHOOL
# 17. EMMA LAZARUS HIGH SCHOOL
# 18. LANDMARK HIGH SCHOOL
# 19. LEGACY SCHOOL FOR INTEGRATED STUDIES
# 20. BAYARD RUSTIN EDUCATIONAL COMPLEX
# 21. VANGUARD HIGH SCHOOL
# 22. MANHATTAN INTERNATIONAL HIGH SCHOOL
# 23. WASHINGTON IRVING HIGH SCHOOL
# 24. UNITY CENTER FOR URBAN TECHNOLOGIES
# 25. MANHATTAN BRIDGES HIGH SCHOOL
# 26. NEW DESIGN HIGH SCHOOL
# 27. INDEPENDENCE HIGH SCHOOL
# 28. LIBERTY HIGH SCHOOL ACADEMY FOR NEWCOMERS
# 29. THE URBAN ASSEMBLY NEW YORK HARBOR SCHOOL
# 30. SATELLITE ACADEMY HIGH SCHOOL
# 31. MANHATTAN COMPREHENSIVE NIGHT AND DAY HIGH SCHOOL
# 32. RICHARD R. GREEN HIGH SCHOOL OF TEACHING
# 33. CHELSEA CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 34. NORMAN THOMAS HIGH SCHOOL
# 35. HIGH SCHOOL OF GRAPHIC COMMUNICATION ARTS
# 36. MANHATTAN THEATRE LAB HIGH SCHOOL
# 37. HIGH SCHOOL FOR ARTS, IMAGINATION AND INQUIRY
# 38. URBAN ASSEMBLY SCHOOL FOR MEDIA STUDIES, THE
# 39. INNOVATION DIPLOMA PLUS
# 40. WADLEIGH SECONDARY SCHOOL FOR THE PERFORMING & VISUAL ARTS
# 41. LOUIS D. BRANDEIS HIGH SCHOOL
# 42. HIGH SCHOOL FOR LAW, ADVOCACY AND COMMUNITY JUSTICE
# 43. EDWARD A. REYNOLDS WEST SIDE HIGH SCHOOL
# 44. FREDERICK DOUGLASS ACADEMY II SECONDARY SCHOOL
# 45. COALITION SCHOOL FOR SOCIAL CHANGE
# 46. PARK EAST HIGH SCHOOL
# 47. CENTRAL PARK EAST HIGH SCHOOL
# 48. ACADEMY OF ENVIRONMENTAL SCIENCE SECONDARY HIGH SCHOOL
# 49. HERITAGE SCHOOL, THE
# 50. HARLEM RENAISSANCE HIGH SCHOOL
# 51. MOTT HALL HIGH SCHOOL
# 52. ACADEMY FOR SOCIAL ACTION: A COLLEGE BOARD SCHOOL
# 53. URBAN ASSEMBLY SCHOOL FOR THE PERFORMING ARTS
# 54. CHOIR ACADEMY OF HARLEM
# 55. THURGOOD MARSHALL ACADEMY FOR LEARNING AND SOCIAL CHANGE
# 56. BREAD & ROSES INTEGRATED ARTS HIGH SCHOOL
# 57. COMMUNITY HEALTH ACADEMY OF THE HEIGHTS
# 58. WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL
# 59. GEORGE WASHINGTON YABC
# 60. HIGH SCHOOL FOR INTERNATIONAL BUSINESS AND FINANCE
# 61. HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS
# 62. HIGH SCHOOL FOR LAW AND PUBLIC SERVICE
# 63. HIGH SCHOOL FOR HEALTH CAREERS AND SCIENCES
# 64. GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND MATHEMATICS
# 65. SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
# 66. CROTONA ACADEMY HIGH SCHOOL
# 67. INTERNATIONAL COMMUNITY HIGH SCHOOL
# 68. COMMUNITY SCHOOL FOR SOCIAL JUSTICE
# 69. MOTT HAVEN VILLAGE PREPARATORY HIGH SCHOOL
# 70. UNIVERSITY HEIGHTS SECONDARY SCHOOL
# 71. FOREIGN LANGUAGE ACADEMY OF GLOBAL STUDIES
# 72. BRONX LEADERSHIP ACADEMY II HIGH SCHOOL
# 73. NEW EXPLORERS HIGH SCHOOL
# 74. URBAN ASSEMBLY SCHOOL FOR CAREERS IN SPORTS
# 75. BRONX ACADEMY OF LETTERS
# 76. ALFRED E. SMITH CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 77. SAMUEL GOMPERS CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 78. HEALTH OPPORTUNITIES HIGH SCHOOL
# 79. WOMEN'S ACADEMY OF EXCELLENCE
# 80. RENAISSANCE HIGH SCHOOL FOR MUSICAL THEATER & TECHNOLOGY
# 81. GATEWAY SCHOOL FOR ENVIRONMENTAL RESEARCH AND TECHNOLOGY
# 82. PABLO NERUDA ACADEMY FOR ARCHITECTURE AND WORLD STUDIES
# 83. MILLENNIUM ART ACADEMY
# 84. HOLCOMBE L. RUCKER SCHOOL OF COMMUNITY RESEARCH
# 85. BRONX COMMUNITY HIGH SCHOOL
# 86. HERBERT H. LEHMAN YABC
# 87. BRONX GUILD
# 88. FELISA RINCON DE GAUTIER INSTITUTE FOR LAW AND PUBLIC POLICY, THE
# 89. BANANA KELLY HIGH SCHOOL
# 90. SCHOOL FOR COMMUNITY RESEARCH AND LEARNING
# 91. HIGH SCHOOL X560 s BRONX ACADEMY HIGH SCHOOL
# 92. JANE ADDAMS HIGH SCHOOL FOR ACADEMIC CAREERS
# 93. BRONX EXPEDITIONARY LEARNING HIGH SCHOOL
# 94. EAGLE ACADEMY FOR YOUNG MEN
# 95. URBAN ASSEMBLY ACADEMY FOR HISTORY AND CITIZENSHIP FOR YOUNG MEN, THE
# 96. EXIMIUS COLLEGE PREPARATORY ACADEMY: A COLLEGE BOARD SCHOOL
# 97. MOTT HALL BRONX HIGH SCHOOL
# 98. VALIDUS PREPARATORY ACADEMY: AN EXPEDITIONARY LEARNING SCHOOL
# 99. LEADERSHIP INSTITUTE
# 100. MORRIS ACADEMY FOR COLLABORATIVE STUDIES
# 101. DREAMYARD PREPARATORY SCHOOL
# 102. ACADEMY FOR LANGUAGE AND TECHNOLOGY
# 103. BRONX INTERNATIONAL HIGH SCHOOL
# 104. SCHOOL FOR EXCELLENCE
# 105. BRONX HIGH SCHOOL OF BUSINESS
# 106. BRONX HIGH SCHOOL FOR MEDICAL SCIENCE
# 107. JONATHAN LEVIN HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS
# 108. BRONX SCHOOL FOR LAW, GOVERNMENT AND JUSTICE
# 109. FREDERICK DOUGLASS ACADEMY III SECONDARY SCHOOL
# 110. BRONX LEADERSHIP ACADEMY HIGH SCHOOL
# 111. HIGH SCHOOL FOR VIOLIN AND DANCE
# 112. BRONX ENGINEERING AND TECHNOLOGY ACADEMY
# 113. THEATRE ARTS PRODUCTION COMPANY SCHOOL
# 114. THE MARIE CURIE SCHOOL FOR MEDICINE, NURSING, AND HEALTH PROFESSIONS
# 115. WEST BRONX ACADEMY FOR THE FUTURE
# 116. KINGSBRIDGE INTERNATIONAL HIGH SCHOOL
# 117. BRONX SCHOOL OF LAW AND FINANCE
# 118. INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# 119. INsTECH ACADEMY (M.S. / HIGH SCHOOL 368)
# 120. KNOWLEDGE AND POWER PREPARATORY ACADEMY INTERNATIONAL HIGH SCHOOL (KAPPA)
# 121. ENGLISH LANGUAGE LEARNERS AND INTERNATIONAL SUPPORT PREPARATORY ACADEMY (ELLIS)
# 122. HIGH SCHOOL FOR TEACHING AND THE PROFESSIONS
# 123. BELMONT PREPARATORY HIGH SCHOOL
# 124. FORDHAM HIGH SCHOOL FOR THE ARTS
# 125. FORDHAM LEADERSHIP ACADEMY FOR BUSINESS AND TECHNOLOGY
# 126. BRONX HIGH SCHOOL FOR LAW AND COMMUNITY SERVICE
# 127. JOHN F. KENNEDY HIGH SCHOOL
# 128. BRONX THEATRE HIGH SCHOOL
# 129. DISCOVERY HIGH SCHOOL
# 130. GRACE DODGE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 131. GRACE DODGE YABC
# 132. BRONX HEALTH SCIENCES HIGH SCHOOL
# 133. BRONX HIGH SCHOOL FOR WRITING AND COMMUNICATION ARTS
# 134. BRONX LAB SCHOOL
# 135. ACADEMY FOR SCHOLARSHIP AND ENTREPRENEURSHIP: A COLLEGE BOARD SCHOOL
# 136. HIGH SCHOOL OF COMPUTERS AND TECHNOLOGY
# 137. BRONX ACADEMY OF HEALTH CAREERS
# 138. ASTOR COLLEGIATE ACADEMY
# 139. CHRISTOPHER COLUMBUS HIGH SCHOOL
# 140. HARRY S TRUMAN HIGH SCHOOL
# 141. NEW WORLD HIGH SCHOOL
# 142. THE BRONXWOOD PREPARATORY ACADEMY
# 143. GLOBAL ENTERPRISE HIGH SCHOOL
# 144. HIGH SCHOOL FOR CONTEMPORARY ARTS
# 145. BRONX AEROSPACE HIGH SCHOOL
# 146. NEW DAY ACADEMY
# 147. METROPOLITAN HIGH SCHOOL, THE
# 148. EXPLORATIONS ACADEMY
# 149. PERFORMANCE CONSERVATORY HIGH SCHOOL
# 150. EAST BRONX ACADEMY FOR THE FUTURE
# 151. PEACE AND DIVERSITY ACADEMY
# 152. PAN AMERICAN INTERNATIONAL HIGH SCHOOL AT MONROE
# 153. ARTURO A. SCHOMBURG SATELLITE ACADEMY BRONX
# 154. BRONX REGIONAL HIGH SCHOOL
# 155. HIGH SCHOOL OF WORLD CULTURES
# 156. FANNIE LOU HAMER FREEDOM HIGH SCHOOL
# 157. WINGS ACADEMY
# 158. MONROE ACADEMY FOR BUSINESS/LAW
# 159. MONROE ACADEMY FOR VISUAL ARTS & DESIGN
# 160. DR. SUSAN S. MCKINNEY SECONDARY SCHOOL OF THE ARTS
# 161. URBAN ASSEMBLY HIGH SCHOOL OF MUSIC AND ART
# 162. BROOKLYN COMMUNITY HIGH SCHOOL OF COMMUNICATION, ARTS AND MEDIA
# 163. SCIENCE SKILLS CENTER HIGH SCHOOL FOR SCIENCE, TECHNOLOGY AND THE CREATIVE ARTS
# 164. BROOKLYN INTERNATIONAL HIGH SCHOOL
# 165. THE URBAN ASSEMBLY SCHOOL FOR LAW AND JUSTICE
# 166. ACORN COMMUNITY HIGH SCHOOL
# 167. FREEDOM ACADEMY HIGH SCHOOL
# 168. BROOKLYN ACADEMY HIGH SCHOOL
# 169. BEDFORD STUYVESANT PREPARATORY HIGH SCHOOL
# 170. GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 171. JUAN MOREL CAMPOS SECONDARY SCHOOL
# 172. ACADEMY FOR YOUNG WRITERS
# 173. GREEN SCHOOL: AN ACADEMY FOR ENVIRONMENTAL CAREERS
# 174. PROGRESS HIGH SCHOOL FOR PROFESSIONAL CAREERS
# 175. SCHOOL FOR LEGAL STUDIES
# 176. THE HIGH SCHOOL FOR ENTERPRISE, BUSINESS AND TECHNOLOGY
# 177. BROOKLYN PREPARATORY HIGH SCHOOL
# 178. WILLIAMSBURG HIGH SCHOOL FOR ARCHITECTURE AND DESIGN
# 179. WILLIAMSBURG PREPARATORY SCHOOL
# 180. LYONS COMMUNITY SCHOOL
# 181. AUTOMOTIVE HIGH SCHOOL
# 182. FRANCES PERKINS ACADEMY
# 183. EL PUENTE ACADEMY FOR PEACE AND JUSTICE
# 184. BROOKLYN SCHOOL FOR GLOBAL STUDIES
# 185. BROOKLYN SECONDARY SCHOOL FOR COLLABORATIVE STUDIES
# 186. SECONDARY SCHOOL FOR LAW
# 187. SECONDARY SCHOOL FOR JOURNALISM
# 188. PARK SLOPE COLLEGIATE
# 189. SCHOOL FOR INTERNATIONAL STUDIES
# 190. COBBLE HILL SCHOOL OF AMERICAN STUDIES
# 191. PACIFIC HIGH SCHOOL
# 192. METROPOLITAN CORPORATE ACADEMY HIGH SCHOOL
# 193. FREDERICK DOUGLASS ACADEMY IV SECONDARY SCHOOL
# 194. BOYS AND GIRLS HIGH SCHOOL
# 195. BROOKLYN HIGH SCHOOL FOR LAW AND TECHNOLOGY
# 196. GOTHAM PROFESSIONAL ARTS ACADEMY
# 197. ACADEMY FOR COLLEGE PREPARATION AND CAREER EXPLORATION: A COLLEGE BOARD SCHOOL
# 198. ACADEMY OF HOSPITALITY AND TOURISM
# 199. W.E.B. DUBOIS ACADEMIC HIGH SCHOOL
# 200. INTERNATIONAL HIGH SCHOOL AT PROSPECT HEIGHTS
# 201. THE HIGH SCHOOL FOR GLOBAL CITIZENSHIP
# 202. SCHOOL FOR HUMAN RIGHTS, THE
# 203. SCHOOL FOR DEMOCRACY AND LEADERSHIP
# 204. HIGH SCHOOL FOR YOUTH AND COMMUNITY DEVELOPMENT AT ERASMUS
# 205. HIGH SCHOOL FOR SERVICE & LEARNING AT ERASMUS
# 206. INTERNATIONAL ARTS BUSINESS SCHOOL
# 207. BROOKLYN ACADEMY OF SCIENCE AND THE ENVIRONMENT
# 208. BROOKLYN SCHOOL FOR MUSIC & THEATRE
# 209. BROWNSVILLE ACADEMY HIGH SCHOOL
# 210. PAUL ROBESON HIGH SCHOOL
# 211. IT TAKES A VILLAGE ACADEMY
# 212. BROOKLYN GENERATION SCHOOL
# 213. BROOKLYN THEATRE ARTS HIGH SCHOOL
# 214. KURT HAHN EXPEDITIONARY LEARNING SCHOOL
# 215. VICTORY COLLEGIATE HIGH SCHOOL
# 216. BROOKLYN BRIDGE ACADEMY
# 217. ARTS & MEDIA PREPARATORY ACADEMY
# 218. HIGH SCHOOL FOR INNOVATION IN ADVERTISING AND MEDIA
# 219. CULTURAL ACADEMY FOR THE ARTS AND SCIENCES
# 220. HIGH SCHOOL FOR MEDICAL PROFESSIONS
# 221. OLYMPUS ACADEMY
# 222. ACADEMY FOR CONSERVATION AND THE ENVIRONMENT
# 223. URBAN ACTION ACADEMY
# 224. EAST BROOKLYN COMMUNITY HIGH SCHOOL
# 225. FDNY HIGH SCHOOL FOR FIRE AND LIFE SAFETY
# 226. HIGH SCHOOL FOR CIVIL RIGHTS
# 227. PERFORMING ARTS AND TECHNOLOGY HIGH SCHOOL
# 228. WORLD ACADEMY FOR TOTAL COMMUNITY HEALTH HIGH SCHOOL
# 229. MULTICULTURAL HIGH SCHOOL
# 230. TRANSIT TECH CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 231. ACADEMY OF INNOVATIVE TECHNOLOGY
# 232. BROOKLYN LAB SCHOOL
# 233. CYPRESS HILLS COLLEGIATE PREPARATORY SCHOOL
# 234. W. H. MAXWELL CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 235. THE SCHOOL FOR CLASSICS: AN ACADEMY OF THINKERS, WRITERS AND PERFORMERS
# 236. FRANKLIN DELANO ROOSEVELT YABC
# 237. INTERNATIONAL HIGH SCHOOL AT LAFAYETTE
# 238. HIGH SCHOOL OF SPORTS MANAGEMENT
# 239. ABRAHAM LINCOLN HIGH SCHOOL
# 240. LIFE ACADEMY HIGH SCHOOL FOR FILM AND MUSIC
# 241. EXPEDITIONARY LEARNING SCHOOL FOR COMMUNITY LEADERS
# 242. WILLIAM E. GRADY CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 243. LIBERATION DIPLOMA PLUS
# 244. SHEEPSHEAD BAY HIGH SCHOOL
# 245. BROOKLYN COLLEGIATE: A COLLEGE BOARD SCHOOL
# 246. FREDERICK DOUGLASS ACADEMY VII HIGH SCHOOL
# 247. BROOKLYN DEMOCRACY ACADEMY
# 248. ASPIRATIONS DIPLOMA PLUS HIGH SCHOOL
# 249. METROPOLITAN DIPLOMA PLUS HIGH SCHOOL
# 250. TEACHERS PREPARATORY HIGH SCHOOL
# 251. HIGH SCHOOL OF APPLIED COMMUNICATION
# 252. PAN AMERICAN INTERNATIONAL HIGH SCHOOL
# 253. NEWTOWN HIGH SCHOOL
# 254. GROVER CLEVELAND HIGH SCHOOL
# 255. MIDDLE COLLEGE HIGH SCHOOL AT LAGUARDIA COMMUNITY COLLEGE
# 256. INTERNATIONAL HIGH SCHOOL AT LAGUARDIA COMMUNITY COLLEGE
# 257. HIGH SCHOOL FOR ARTS AND BUSINESS
# 258. FLUSHING INTERNATIONAL HIGH SCHOOL
# 259. FLUSHING HIGH SCHOOL
# 260. FLUSHING YABC
# 261. QUEENS ACADEMY HIGH SCHOOL
# 262. NORTH QUEENS COMMUNITY HIGH SCHOOL
# 263. MARTIN VAN BUREN HIGH SCHOOL
# 264. FREDERICK DOUGLASS ACADEMY VI HIGH SCHOOL
# 265. QUEENS HIGH SCHOOL FOR INFORMATION, RESEARCH, AND TECHNOLOGY
# 266. ACADEMY OF MEDICAL TECHNOLOGY: A COLLEGE BOARD SCHOOL
# 267. AUGUST MARTIN HIGH SCHOOL
# 268. BEACH CHANNEL HIGH SCHOOL
# 269. RICHMOND HILL HIGH SCHOOL
# 270. JOHN ADAMS HIGH SCHOOL
# 271. QUEENS SATELLITE HIGH SCHOOL FOR OPPORTUNITY
# 272. JAMAICA HIGH SCHOOL
# 273. HILLCREST HIGH SCHOOL
# 274. HIGH SCHOOL FOR LAW ENFORCEMENT AND PUBLIC SAFETY
# 275. QUEENS PREPARATORY ACADEMY
# 276. PATHWAYS COLLEGE PREPARATORY SCHOOL: A COLLEGE BOARD SCHOOL
# 277. EXCELSIOR PREPARATORY HIGH SCHOOL
# 278. PREPARATORY ACADEMY FOR WRITERS: A COLLEGE BOARD SCHOOL
# 279. MATHEMATICS, SCIENCE RESEARCH AND TECHNOLOGY MAGNET HIGH SCHOOL
# 280. LAW, GOVERNMENT AND COMMUNITY SERVICE HIGH SCHOOL
# 281. BUSINESS, COMPUTER APPLICATIONS & ENTREPRENEURSHIP HIGH SCHOOL
# 282. HUMANITIES & ARTS MAGNET HIGH SCHOOL
# 283. LONG ISLAND CITY HIGH SCHOOL
# 284. NEWCOMERS HIGH SCHOOL
# 285. GAYNOR MCCOWN EXPEDITIONARY LEARNING SCHOOL
# 286. YOUNG ADULT BOROUGH CENTER AT STATEN IS TECH HS
# 287. ACADEMY FOR ENVIRONMENTAL LEADERSHIP
# 288. EBC HIGH SCHOOL FOR PUBLIC SERVICE–BUSHWICK
# 289. BUSHWICK SCHOOL FOR SOCIAL JUSTICE
# 290. ACADEMY OF URBAN PLANNING
# 291. BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCELLENCE
# 292. BUSHWICK COMMUNITY HIGH SCHOOL
# 293. PHOENIX ACADEMY
#
# Cluster 2:
# 1. NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND MATH HIGH SCHOOL
# 2. BARD HIGH SCHOOL EARLY COLLEGE
# 3. BARUCH COLLEGE CAMPUS HIGH SCHOOL
# 4. N.Y.C. LAB SCHOOL FOR COLLABORATIVE STUDIES
# 5. SCHOOL OF THE FUTURE HIGH SCHOOL
# 6. ELEANOR ROOSEVELT HIGH SCHOOL
# 7. MILLENNIUM HIGH SCHOOL
# 8. STUYVESANT HIGH SCHOOL
# 9. URBAN ACADEMY LABORATORY HIGH SCHOOL
# 10. BEACON HIGH SCHOOL
# 11. FIORELLO H. LAGUARDIA HIGH SCHOOL OF MUSIC & ART AND PERFORMING ARTS
# 12. HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGINEERING AT CITY COLLEGE
# 13. BRONX HIGH SCHOOL OF SCIENCE
# 14. HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE
# 15. BROOKLYN TECHNICAL HIGH SCHOOL
# 16. BROOKLYN LATIN SCHOOL, THE
# 17. LEON M. GOLDSTEIN HIGH SCHOOL FOR THE SCIENCES
# 18. BARD HIGH SCHOOL EARLY COLLEGE II
# 19. TOWNSEND HARRIS HIGH SCHOOL
# 20. QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK COLLEGE
# 21. BACCALAUREATE SCHOOL FOR GLOBAL EDUCATION
# 22. STATEN ISLAND TECHNICAL HIGH SCHOOL

# %%
# Pie charts for each average score
for col in ['SAT Critical Reading Avg. Score', 'SAT Math Avg. Score', 'SAT Writing Avg. Score']:
    data[col] = pd.to_numeric(data[col], errors='coerce')
    cluster_avg = data.groupby('Cluster')[col].mean()
    
    # Plot pie chart
    plt.figure(figsize=(8, 6))
    plt.pie(cluster_avg, labels=cluster_avg.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'Average {col} by Cluster')
    plt.show()

# %%
# We need to check how many took the test at their school. More specifically, the total average of every cluster

# Convert 'Num of SAT Test Takers' column to numeric
data['Num of SAT Test Takers'] = pd.to_numeric(data['Num of SAT Test Takers'], errors='coerce')

# Average Num of SAT Test Takers for every cluster
cluster_avg_num_test_takers = data.groupby('Cluster')['Num of SAT Test Takers'].mean()

plt.figure(figsize=(8, 6))
barplot = sns.barplot(x=cluster_avg_num_test_takers.index, y=cluster_avg_num_test_takers.values, palette='viridis')
plt.title('Average Num of SAT Test Takers for Every Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Num of SAT Test Takers')

# Annotate bars with the final number of test takers
for i, num_test_takers in enumerate(cluster_avg_num_test_takers):
    barplot.text(i, num_test_takers + 5, f'{num_test_takers:.2f}', ha='center', fontsize=10)

plt.show()
# Out:
# C:\Users\stavros\AppData\Local\Temp\ipykernel_14456\918897150.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=cluster_avg_num_test_takers.index, y=cluster_avg_num_test_takers.values, palette='viridis')

# %% [markdown]
# **DBSCAN BELOW**

# %%
# Apply DBSCAN clustering algorithm
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters_db = dbscan.fit_predict(scaled_features)

# Add cluster labels to the dataset
data['Cluster_DBSCAN'] = clusters_db

# Get unique cluster labels
unique_clusters_db = np.unique(clusters_db)

# Define colors for each cluster
cluster_colors_db = {cluster: color for cluster, color in zip(unique_clusters_db, sns.color_palette('tab10', len(unique_clusters_db)))}

# Visualization: Plot DBSCAN clusters in reduced dimensionality space
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_features[:, 0], y=pca_features[:, 1], hue=data['Cluster_DBSCAN'], palette=cluster_colors_db, legend='full')
plt.title('DBSCAN Clustering of Schools based on Exam Performance')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
# Count the number of schools in each cluster
cluster_counts_db = data['Cluster_DBSCAN'].value_counts()

# Sort the cluster counts from smallest to largest
cluster_counts_db = cluster_counts_db.sort_index()

# Create a bar plot showing the number of schools in each cluster
plt.figure(figsize=(8, 6))
barplot_db = sns.barplot(x=cluster_counts_db.index, y=cluster_counts_db.values, palette='viridis')

# Annotate each bar with its value
for i, count in enumerate(cluster_counts_db):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=10)

plt.title('Number of Schools in Each Cluster (DBSCAN)')
plt.xlabel('Clusters')
plt.ylabel('Number of Schools')

plt.show()
# Out:
# C:\Users\stavros\AppData\Local\Temp\ipykernel_14456\1387112060.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot_db = sns.barplot(x=cluster_counts_db.index, y=cluster_counts_db.values, palette='viridis')

# %%
# Iterate over each cluster
for cluster_num in range(-1,3):
    # Get the schools in the current cluster
    cluster_schools = data[data['Cluster_DBSCAN'] == cluster_num]['SCHOOL NAME']
    
    # Print the cluster number
    print(f"Cluster {cluster_num}:")
    
    # Print each school in the cluster
    for i, school in enumerate(cluster_schools, start=1):
        print(f"{i}. {school}")
    
    # Add an empty line between clusters
    print()
# Out:
# Cluster -1:
# 1. LOWER EAST SIDE PREPARATORY HIGH SCHOOL
# 2. BARD HIGH SCHOOL EARLY COLLEGE
# 3. EMMA LAZARUS HIGH SCHOOL
# 4. PROFESSIONAL PERFORMING ARTS HIGH SCHOOL
# 5. BARUCH COLLEGE CAMPUS HIGH SCHOOL
# 6. ELEANOR ROOSEVELT HIGH SCHOOL
# 7. STUYVESANT HIGH SCHOOL
# 8. HIGH SCHOOL FOR DUAL LANGUAGE AND ASIAN STUDIES
# 9. MANHATTAN COMPREHENSIVE NIGHT AND DAY HIGH SCHOOL
# 10. BEACON HIGH SCHOOL
# 11. FIORELLO H. LAGUARDIA HIGH SCHOOL OF MUSIC & ART AND PERFORMING ARTS
# 12. HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGINEERING AT CITY COLLEGE
# 13. BRONX HIGH SCHOOL OF SCIENCE
# 14. HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE
# 15. BROOKLYN TECHNICAL HIGH SCHOOL
# 16. BROOKLYN LATIN SCHOOL, THE
# 17. FRANKLIN DELANO ROOSEVELT HIGH SCHOOL
# 18. FRANKLIN DELANO ROOSEVELT YABC
# 19. FLUSHING INTERNATIONAL HIGH SCHOOL
# 20. TOWNSEND HARRIS HIGH SCHOOL
# 21. QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK COLLEGE
# 22. NEWCOMERS HIGH SCHOOL
# 23. STATEN ISLAND TECHNICAL HIGH SCHOOL
# 24. GED PLUS s CITYWIDE
#
# Cluster 0:
# 1. HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 2. UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 3. EAST SIDE COMMUNITY SCHOOL
# 4. FORSYTH SATELLITE ACADEMY
# 5. MARTA VALLE HIGH SCHOOL
# 6. CASCADES HIGH SCHOOL
# 7. 47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL
# 8. FOOD AND FINANCE HIGH SCHOOL
# 9. ESSEX STREET ACADEMY
# 10. HIGH SCHOOL OF HOSPITALITY MANAGEMENT
# 11. PACE HIGH SCHOOL
# 12. URBAN ASSEMBLY SCHOOL OF DESIGN AND CONSTRUCTION, THE
# 13. FACING HISTORY SCHOOL, THE
# 14. URBAN ASSEMBLY ACADEMY OF GOVERNMENT AND LAW, THE
# 15. LOWER MANHATTAN ARTS ACADEMY
# 16. JAMES BALDWIN SCHOOL, THE: A SCHOOL FOR EXPEDITIONARY LEARNING
# 17. URBAN ASSEMBLY SCHOOL OF BUSINESS FOR YOUNG WOMEN, THE
# 18. GRAMERCY ARTS HIGH SCHOOL
# 19. NYC ISCHOOL
# 20. HIGH SCHOOL FOR ENVIRONMENTAL STUDIES
# 21. INSTITUTE FOR COLLABORATIVE EDUCATION
# 22. N.Y.C. MUSEUM SCHOOL
# 23. LANDMARK HIGH SCHOOL
# 24. HIGH SCHOOL FOR HEALTH PROFESSIONS AND HUMAN SERVICES
# 25. LEADERSHIP AND PUBLIC SERVICE HIGH SCHOOL
# 26. LEGACY SCHOOL FOR INTEGRATED STUDIES
# 27. MANHATTAN VILLAGE ACADEMY
# 28. BAYARD RUSTIN EDUCATIONAL COMPLEX
# 29. VANGUARD HIGH SCHOOL
# 30. MANHATTAN INTERNATIONAL HIGH SCHOOL
# 31. WASHINGTON IRVING HIGH SCHOOL
# 32. HIGH SCHOOL OF ECONOMICS AND FINANCE
# 33. UNITY CENTER FOR URBAN TECHNOLOGIES
# 34. TALENT UNLIMITED HIGH SCHOOL
# 35. MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 36. JACQUELINE KENNEDY ONASSIS HIGH SCHOOL
# 37. REPERTORY COMPANY HIGH SCHOOL FOR THEATRE ARTS
# 38. MANHATTAN BRIDGES HIGH SCHOOL
# 39. NEW DESIGN HIGH SCHOOL
# 40. INDEPENDENCE HIGH SCHOOL
# 41. LIBERTY HIGH SCHOOL ACADEMY FOR NEWCOMERS
# 42. THE URBAN ASSEMBLY NEW YORK HARBOR SCHOOL
# 43. HIGH SCHOOL M560 s CITY AS SCHOOL
# 44. SATELLITE ACADEMY HIGH SCHOOL
# 45. RICHARD R. GREEN HIGH SCHOOL OF TEACHING
# 46. HARVEY MILK HIGH SCHOOL
# 47. THE HIGH SCHOOL OF FASHION INDUSTRIES
# 48. HUMANITIES PREPARATORY ACADEMY
# 49. CHELSEA CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 50. NORMAN THOMAS HIGH SCHOOL
# 51. HIGH SCHOOL OF GRAPHIC COMMUNICATION ARTS
# 52. ART AND DESIGN HIGH SCHOOL
# 53. LIFE SCIENCES SECONDARY SCHOOL
# 54. MANHATTAN THEATRE LAB HIGH SCHOOL
# 55. HIGH SCHOOL FOR ARTS, IMAGINATION AND INQUIRY
# 56. URBAN ASSEMBLY SCHOOL FOR MEDIA STUDIES, THE
# 57. INNOVATION DIPLOMA PLUS
# 58. WADLEIGH SECONDARY SCHOOL FOR THE PERFORMING & VISUAL ARTS
# 59. LOUIS D. BRANDEIS HIGH SCHOOL
# 60. HIGH SCHOOL FOR LAW, ADVOCACY AND COMMUNITY JUSTICE
# 61. HIGH SCHOOL OF ARTS AND TECHNOLOGY
# 62. EDWARD A. REYNOLDS WEST SIDE HIGH SCHOOL
# 63. MANHATTAN / HUNTER SCIENCE HIGH SCHOOL
# 64. FREDERICK DOUGLASS ACADEMY II SECONDARY SCHOOL
# 65. COALITION SCHOOL FOR SOCIAL CHANGE
# 66. MANHATTAN CENTER FOR SCIENCE AND MATHEMATICS
# 67. PARK EAST HIGH SCHOOL
# 68. CENTRAL PARK EAST HIGH SCHOOL
# 69. YOUNG WOMEN'S LEADERSHIP SCHOOL
# 70. ACADEMY OF ENVIRONMENTAL SCIENCE SECONDARY HIGH SCHOOL
# 71. HERITAGE SCHOOL, THE
# 72. HARLEM RENAISSANCE HIGH SCHOOL
# 73. MOTT HALL HIGH SCHOOL
# 74. ACADEMY FOR SOCIAL ACTION: A COLLEGE BOARD SCHOOL
# 75. URBAN ASSEMBLY SCHOOL FOR THE PERFORMING ARTS
# 76. CHOIR ACADEMY OF HARLEM
# 77. FREDERICK DOUGLASS ACADEMY
# 78. THURGOOD MARSHALL ACADEMY FOR LEARNING AND SOCIAL CHANGE
# 79. BREAD & ROSES INTEGRATED ARTS HIGH SCHOOL
# 80. CITY COLLEGE ACADEMY OF THE ARTS
# 81. COMMUNITY HEALTH ACADEMY OF THE HEIGHTS
# 82. WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL
# 83. GEORGE WASHINGTON YABC
# 84. HIGH SCHOOL FOR INTERNATIONAL BUSINESS AND FINANCE
# 85. HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS
# 86. HIGH SCHOOL FOR LAW AND PUBLIC SERVICE
# 87. HIGH SCHOOL FOR HEALTH CAREERS AND SCIENCES
# 88. A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL
# 89. GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND MATHEMATICS
# 90. SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
# 91. CROTONA ACADEMY HIGH SCHOOL
# 92. COMMUNITY SCHOOL FOR SOCIAL JUSTICE
# 93. MOTT HAVEN VILLAGE PREPARATORY HIGH SCHOOL
# 94. UNIVERSITY HEIGHTS SECONDARY SCHOOL
# 95. HOSTOSsLINCOLN ACADEMY OF SCIENCE
# 96. FOREIGN LANGUAGE ACADEMY OF GLOBAL STUDIES
# 97. BRONX LEADERSHIP ACADEMY II HIGH SCHOOL
# 98. NEW EXPLORERS HIGH SCHOOL
# 99. URBAN ASSEMBLY SCHOOL FOR CAREERS IN SPORTS
# 100. BRONX ACADEMY OF LETTERS
# 101. ALFRED E. SMITH CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 102. SAMUEL GOMPERS CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 103. HEALTH OPPORTUNITIES HIGH SCHOOL
# 104. WOMEN'S ACADEMY OF EXCELLENCE
# 105. RENAISSANCE HIGH SCHOOL FOR MUSICAL THEATER & TECHNOLOGY
# 106. GATEWAY SCHOOL FOR ENVIRONMENTAL RESEARCH AND TECHNOLOGY
# 107. PABLO NERUDA ACADEMY FOR ARCHITECTURE AND WORLD STUDIES
# 108. MILLENNIUM ART ACADEMY
# 109. HOLCOMBE L. RUCKER SCHOOL OF COMMUNITY RESEARCH
# 110. BRONX COMMUNITY HIGH SCHOOL
# 111. HERBERT H. LEHMAN HIGH SCHOOL
# 112. HERBERT H. LEHMAN YABC
# 113. BRONX GUILD
# 114. FELISA RINCON DE GAUTIER INSTITUTE FOR LAW AND PUBLIC POLICY, THE
# 115. BANANA KELLY HIGH SCHOOL
# 116. SCHOOL FOR COMMUNITY RESEARCH AND LEARNING
# 117. HIGH SCHOOL X560 s BRONX ACADEMY HIGH SCHOOL
# 118. JANE ADDAMS HIGH SCHOOL FOR ACADEMIC CAREERS
# 119. BRONX EXPEDITIONARY LEARNING HIGH SCHOOL
# 120. EAGLE ACADEMY FOR YOUNG MEN
# 121. URBAN ASSEMBLY ACADEMY FOR HISTORY AND CITIZENSHIP FOR YOUNG MEN, THE
# 122. URBAN ASSEMBLY SCHOOL FOR APPLIED MATH AND SCIENCE, THE
# 123. EXIMIUS COLLEGE PREPARATORY ACADEMY: A COLLEGE BOARD SCHOOL
# 124. MOTT HALL BRONX HIGH SCHOOL
# 125. BRONX CENTER FOR SCIENCE AND MATHEMATICS
# 126. VALIDUS PREPARATORY ACADEMY: AN EXPEDITIONARY LEARNING SCHOOL
# 127. LEADERSHIP INSTITUTE
# 128. MORRIS ACADEMY FOR COLLABORATIVE STUDIES
# 129. DREAMYARD PREPARATORY SCHOOL
# 130. SCHOOL FOR EXCELLENCE
# 131. BRONX HIGH SCHOOL OF BUSINESS
# 132. BRONX HIGH SCHOOL FOR MEDICAL SCIENCE
# 133. JONATHAN LEVIN HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS
# 134. BRONX SCHOOL FOR LAW, GOVERNMENT AND JUSTICE
# 135. FREDERICK DOUGLASS ACADEMY III SECONDARY SCHOOL
# 136. BRONX LEADERSHIP ACADEMY HIGH SCHOOL
# 137. HIGH SCHOOL FOR VIOLIN AND DANCE
# 138. RIVERDALE / KINGSBRIDGE ACADEMY (MIDDLE SCHOOL / HIGH SCHOOL 141)
# 139. BRONX ENGINEERING AND TECHNOLOGY ACADEMY
# 140. THEATRE ARTS PRODUCTION COMPANY SCHOOL
# 141. THE MARIE CURIE SCHOOL FOR MEDICINE, NURSING, AND HEALTH PROFESSIONS
# 142. WEST BRONX ACADEMY FOR THE FUTURE
# 143. BRONX SCHOOL OF LAW AND FINANCE
# 144. INsTECH ACADEMY (M.S. / HIGH SCHOOL 368)
# 145. KNOWLEDGE AND POWER PREPARATORY ACADEMY INTERNATIONAL HIGH SCHOOL (KAPPA)
# 146. ENGLISH LANGUAGE LEARNERS AND INTERNATIONAL SUPPORT PREPARATORY ACADEMY (ELLIS)
# 147. HIGH SCHOOL FOR TEACHING AND THE PROFESSIONS
# 148. BELMONT PREPARATORY HIGH SCHOOL
# 149. FORDHAM HIGH SCHOOL FOR THE ARTS
# 150. FORDHAM LEADERSHIP ACADEMY FOR BUSINESS AND TECHNOLOGY
# 151. BRONX HIGH SCHOOL FOR LAW AND COMMUNITY SERVICE
# 152. DEWITT CLINTON HIGH SCHOOL
# 153. CELIA CRUZ BRONX HIGH SCHOOL OF MUSIC, THE
# 154. JOHN F. KENNEDY HIGH SCHOOL
# 155. MARBLE HILL HIGH SCHOOL FOR INTERNATIONAL STUDIES
# 156. BRONX THEATRE HIGH SCHOOL
# 157. DISCOVERY HIGH SCHOOL
# 158. GRACE DODGE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 159. GRACE DODGE YABC
# 160. BRONX HEALTH SCIENCES HIGH SCHOOL
# 161. BRONX HIGH SCHOOL FOR WRITING AND COMMUNICATION ARTS
# 162. BRONX LAB SCHOOL
# 163. ACADEMY FOR SCHOLARSHIP AND ENTREPRENEURSHIP: A COLLEGE BOARD SCHOOL
# 164. HIGH SCHOOL OF COMPUTERS AND TECHNOLOGY
# 165. COLLEGIATE INSTITUTE FOR MATH AND SCIENCE
# 166. BRONX ACADEMY OF HEALTH CAREERS
# 167. ASTOR COLLEGIATE ACADEMY
# 168. CHRISTOPHER COLUMBUS HIGH SCHOOL
# 169. BRONX HIGH SCHOOL FOR THE VISUAL ARTS
# 170. HARRY S TRUMAN HIGH SCHOOL
# 171. NEW WORLD HIGH SCHOOL
# 172. THE BRONXWOOD PREPARATORY ACADEMY
# 173. GLOBAL ENTERPRISE HIGH SCHOOL
# 174. PELHAM PREPARATORY ACADEMY
# 175. HIGH SCHOOL FOR CONTEMPORARY ARTS
# 176. BRONX AEROSPACE HIGH SCHOOL
# 177. NEW DAY ACADEMY
# 178. METROPOLITAN HIGH SCHOOL, THE
# 179. EXPLORATIONS ACADEMY
# 180. PERFORMANCE CONSERVATORY HIGH SCHOOL
# 181. BRONX LATIN
# 182. EAST BRONX ACADEMY FOR THE FUTURE
# 183. PEACE AND DIVERSITY ACADEMY
# 184. ARTURO A. SCHOMBURG SATELLITE ACADEMY BRONX
# 185. BRONX REGIONAL HIGH SCHOOL
# 186. FANNIE LOU HAMER FREEDOM HIGH SCHOOL
# 187. WINGS ACADEMY
# 188. MONROE ACADEMY FOR BUSINESS/LAW
# 189. MONROE ACADEMY FOR VISUAL ARTS & DESIGN
# 190. DR. SUSAN S. MCKINNEY SECONDARY SCHOOL OF THE ARTS
# 191. ACADEMY OF BUSINESS AND COMMUNITY DEVELOPMENT
# 192. URBAN ASSEMBLY HIGH SCHOOL OF MUSIC AND ART
# 193. BROOKLYN COMMUNITY HIGH SCHOOL OF COMMUNICATION, ARTS AND MEDIA
# 194. SCIENCE SKILLS CENTER HIGH SCHOOL FOR SCIENCE, TECHNOLOGY AND THE CREATIVE ARTS
# 195. THE URBAN ASSEMBLY SCHOOL FOR LAW AND JUSTICE
# 196. ACORN COMMUNITY HIGH SCHOOL
# 197. FREEDOM ACADEMY HIGH SCHOOL
# 198. BROOKLYN ACADEMY HIGH SCHOOL
# 199. BEDFORD STUYVESANT PREPARATORY HIGH SCHOOL
# 200. BEDFORD ACADEMY HIGH SCHOOL
# 201. GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 202. BENJAMIN BANNEKER ACADEMY
# 203. CITY POLYTECHNIC HIGH SCHOOL OF ENGINEERING, ARCHITECTURE, AND TECHNOLOGY
# 204. JUAN MOREL CAMPOS SECONDARY SCHOOL
# 205. ACADEMY FOR YOUNG WRITERS
# 206. GREEN SCHOOL: AN ACADEMY FOR ENVIRONMENTAL CAREERS
# 207. PROGRESS HIGH SCHOOL FOR PROFESSIONAL CAREERS
# 208. SCHOOL FOR LEGAL STUDIES
# 209. THE HIGH SCHOOL FOR ENTERPRISE, BUSINESS AND TECHNOLOGY
# 210. BROOKLYN PREPARATORY HIGH SCHOOL
# 211. WILLIAMSBURG HIGH SCHOOL FOR ARCHITECTURE AND DESIGN
# 212. WILLIAMSBURG PREPARATORY SCHOOL
# 213. LYONS COMMUNITY SCHOOL
# 214. AUTOMOTIVE HIGH SCHOOL
# 215. FRANCES PERKINS ACADEMY
# 216. EL PUENTE ACADEMY FOR PEACE AND JUSTICE
# 217. BROOKLYN SCHOOL FOR GLOBAL STUDIES
# 218. BROOKLYN SECONDARY SCHOOL FOR COLLABORATIVE STUDIES
# 219. SECONDARY SCHOOL FOR LAW
# 220. SECONDARY SCHOOL FOR JOURNALISM
# 221. PARK SLOPE COLLEGIATE
# 222. SCHOOL FOR INTERNATIONAL STUDIES
# 223. COBBLE HILL SCHOOL OF AMERICAN STUDIES
# 224. PACIFIC HIGH SCHOOL
# 225. METROPOLITAN CORPORATE ACADEMY HIGH SCHOOL
# 226. BROOKLYN HIGH SCHOOL OF THE ARTS
# 227. SOUTH BROOKLYN COMMUNITY HIGH SCHOOL
# 228. FREDERICK DOUGLASS ACADEMY IV SECONDARY SCHOOL
# 229. BOYS AND GIRLS HIGH SCHOOL
# 230. BROOKLYN HIGH SCHOOL FOR LAW AND TECHNOLOGY
# 231. GOTHAM PROFESSIONAL ARTS ACADEMY
# 232. ACADEMY FOR COLLEGE PREPARATION AND CAREER EXPLORATION: A COLLEGE BOARD SCHOOL
# 233. ACADEMY OF HOSPITALITY AND TOURISM
# 234. W.E.B. DUBOIS ACADEMIC HIGH SCHOOL
# 235. THE HIGH SCHOOL FOR GLOBAL CITIZENSHIP
# 236. SCHOOL FOR HUMAN RIGHTS, THE
# 237. SCHOOL FOR DEMOCRACY AND LEADERSHIP
# 238. HIGH SCHOOL FOR YOUTH AND COMMUNITY DEVELOPMENT AT ERASMUS
# 239. HIGH SCHOOL FOR SERVICE & LEARNING AT ERASMUS
# 240. SCIENCE, TECHNOLOGY AND RESEARCH EARLY COLLEGE HIGH SCHOOL AT ERASMUS
# 241. INTERNATIONAL ARTS BUSINESS SCHOOL
# 242. HIGH SCHOOL FOR PUBLIC SERVICE: HEROES OF TOMORROW
# 243. BROOKLYN ACADEMY OF SCIENCE AND THE ENVIRONMENT
# 244. BROOKLYN SCHOOL FOR MUSIC & THEATRE
# 245. BROWNSVILLE ACADEMY HIGH SCHOOL
# 246. MEDGAR EVERS COLLEGE PREPARATORY SCHOOL
# 247. CLARA BARTON HIGH SCHOOL
# 248. PAUL ROBESON HIGH SCHOOL
# 249. BROOKLYN GENERATION SCHOOL
# 250. BROOKLYN THEATRE ARTS HIGH SCHOOL
# 251. KURT HAHN EXPEDITIONARY LEARNING SCHOOL
# 252. VICTORY COLLEGIATE HIGH SCHOOL
# 253. BROOKLYN BRIDGE ACADEMY
# 254. ARTS & MEDIA PREPARATORY ACADEMY
# 255. HIGH SCHOOL FOR INNOVATION IN ADVERTISING AND MEDIA
# 256. CULTURAL ACADEMY FOR THE ARTS AND SCIENCES
# 257. HIGH SCHOOL FOR MEDICAL PROFESSIONS
# 258. OLYMPUS ACADEMY
# 259. ACADEMY FOR CONSERVATION AND THE ENVIRONMENT
# 260. URBAN ACTION ACADEMY
# 261. EAST BROOKLYN COMMUNITY HIGH SCHOOL
# 262. EAST NEW YORK FAMILY ACADEMY
# 263. FDNY HIGH SCHOOL FOR FIRE AND LIFE SAFETY
# 264. HIGH SCHOOL FOR CIVIL RIGHTS
# 265. PERFORMING ARTS AND TECHNOLOGY HIGH SCHOOL
# 266. WORLD ACADEMY FOR TOTAL COMMUNITY HEALTH HIGH SCHOOL
# 267. TRANSIT TECH CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 268. ACADEMY OF INNOVATIVE TECHNOLOGY
# 269. BROOKLYN LAB SCHOOL
# 270. CYPRESS HILLS COLLEGIATE PREPARATORY SCHOOL
# 271. W. H. MAXWELL CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 272. THE SCHOOL FOR CLASSICS: AN ACADEMY OF THINKERS, WRITERS AND PERFORMERS
# 273. NEW UTRECHT HIGH SCHOOL
# 274. HIGH SCHOOL OF TELECOMMUNICATION ARTS AND TECHNOLOGY
# 275. FORT HAMILTON HIGH SCHOOL
# 276. INTERNATIONAL HIGH SCHOOL AT LAFAYETTE
# 277. RACHEL CARSON HIGH SCHOOL FOR COASTAL STUDIES
# 278. HIGH SCHOOL OF SPORTS MANAGEMENT
# 279. ABRAHAM LINCOLN HIGH SCHOOL
# 280. EDWARD R. MURROW HIGH SCHOOL
# 281. JOHN DEWEY HIGH SCHOOL
# 282. LIFE ACADEMY HIGH SCHOOL FOR FILM AND MUSIC
# 283. EXPEDITIONARY LEARNING SCHOOL FOR COMMUNITY LEADERS
# 284. WILLIAM E. GRADY CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 285. BROOKLYN STUDIO SECONDARY SCHOOL
# 286. LIBERATION DIPLOMA PLUS
# 287. MIDWOOD HIGH SCHOOL
# 288. JAMES MADISON HIGH SCHOOL
# 289. SHEEPSHEAD BAY HIGH SCHOOL
# 290. BROOKLYN COLLEGE ACADEMY
# 291. BROOKLYN COLLEGIATE: A COLLEGE BOARD SCHOOL
# 292. FREDERICK DOUGLASS ACADEMY VII HIGH SCHOOL
# 293. BROOKLYN DEMOCRACY ACADEMY
# 294. METROPOLITAN DIPLOMA PLUS HIGH SCHOOL
# 295. TEACHERS PREPARATORY HIGH SCHOOL
# 296. ACADEMY OF FINANCE AND ENTERPRISE
# 297. HIGH SCHOOL OF APPLIED COMMUNICATION
# 298. CIVIC LEADERSHIP ACADEMY
# 299. NEWTOWN HIGH SCHOOL
# 300. GROVER CLEVELAND HIGH SCHOOL
# 301. MIDDLE COLLEGE HIGH SCHOOL AT LAGUARDIA COMMUNITY COLLEGE
# 302. INTERNATIONAL HIGH SCHOOL AT LAGUARDIA COMMUNITY COLLEGE
# 303. HIGH SCHOOL FOR ARTS AND BUSINESS
# 304. ROBERT F. WAGNER, JR. SECONDARY SCHOOL FOR ARTS AND TECHNOLOGY
# 305. QUEENS VOCATIONAL AND TECHNICAL HIGH SCHOOL
# 306. AVIATION CAREER & TECHNICAL EDUCATION HIGH SCHOOL
# 307. QUEENS SCHOOL OF INQUIRY, THE
# 308. EASTsWEST SCHOOL OF INTERNATIONAL STUDIES
# 309. WORLD JOURNALISM PREPARATORY: A COLLEGE BOARD SCHOOL
# 310. JOHN BOWNE HIGH SCHOOL
# 311. FLUSHING HIGH SCHOOL
# 312. FLUSHING YABC
# 313. QUEENS ACADEMY HIGH SCHOOL
# 314. ROBERT F. KENNEDY COMMUNITY HIGH SCHOOL
# 315. NORTH QUEENS COMMUNITY HIGH SCHOOL
# 316. BENJAMIN N. CARDOZO HIGH SCHOOL
# 317. FRANCIS LEWIS HIGH SCHOOL
# 318. MARTIN VAN BUREN HIGH SCHOOL
# 319. BAYSIDE HIGH SCHOOL
# 320. QUEENS HIGH SCHOOL OF TEACHING, LIBERAL ARTS AND THE SCIENCES
# 321. FREDERICK DOUGLASS ACADEMY VI HIGH SCHOOL
# 322. CHANNEL VIEW SCHOOL FOR RESEARCH
# 323. QUEENS HIGH SCHOOL FOR INFORMATION, RESEARCH, AND TECHNOLOGY
# 324. ROBERT H. GODDARD HIGH SCHOOL OF COMMUNICATION ARTS AND TECHNOLOGY
# 325. ACADEMY OF MEDICAL TECHNOLOGY: A COLLEGE BOARD SCHOOL
# 326. AUGUST MARTIN HIGH SCHOOL
# 327. BEACH CHANNEL HIGH SCHOOL
# 328. RICHMOND HILL HIGH SCHOOL
# 329. JOHN ADAMS HIGH SCHOOL
# 330. HIGH SCHOOL FOR CONSTRUCTION TRADES, ENGINEERING AND ARCHITECTURE
# 331. QUEENS COLLEGIATE: A COLLEGE BOARD SCHOOL
# 332. QUEENS SATELLITE HIGH SCHOOL FOR OPPORTUNITY
# 333. JAMAICA GATEWAY TO THE SCIENCES
# 334. FOREST HILLS HIGH SCHOOL
# 335. JAMAICA HIGH SCHOOL
# 336. HILLCREST HIGH SCHOOL
# 337. THOMAS A. EDISON CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 338. HIGH SCHOOL FOR LAW ENFORCEMENT AND PUBLIC SAFETY
# 339. YOUNG WOMEN'S LEADERSHIP SCHOOL, QUEENS
# 340. QUEENS PREPARATORY ACADEMY
# 341. PATHWAYS COLLEGE PREPARATORY SCHOOL: A COLLEGE BOARD SCHOOL
# 342. EXCELSIOR PREPARATORY HIGH SCHOOL
# 343. GEORGE WASHINGTON CARVER HIGH SCHOOL FOR THE SCIENCES
# 344. PREPARATORY ACADEMY FOR WRITERS: A COLLEGE BOARD SCHOOL
# 345. MATHEMATICS, SCIENCE RESEARCH AND TECHNOLOGY MAGNET HIGH SCHOOL
# 346. LAW, GOVERNMENT AND COMMUNITY SERVICE HIGH SCHOOL
# 347. BUSINESS, COMPUTER APPLICATIONS & ENTREPRENEURSHIP HIGH SCHOOL
# 348. HUMANITIES & ARTS MAGNET HIGH SCHOOL
# 349. ACADEMY FOR CAREERS IN TELEVISION AND FILM
# 350. WILLIAM CULLEN BRYANT HIGH SCHOOL
# 351. LONG ISLAND CITY HIGH SCHOOL
# 352. FRANK SINATRA SCHOOL OF THE ARTS HIGH SCHOOL
# 353. INFORMATION TECHNOLOGY HIGH SCHOOL
# 354. ACADEMY OF AMERICAN STUDIES
# 355. CSI HIGH SCHOOL FOR INTERNATIONAL STUDIES
# 356. GAYNOR MCCOWN EXPEDITIONARY LEARNING SCHOOL
# 357. THE MICHAEL J. PETRIDES SCHOOL
# 358. NEW DORP HIGH SCHOOL
# 359. PORT RICHMOND HIGH SCHOOL
# 360. CURTIS HIGH SCHOOL
# 361. TOTTENVILLE HIGH SCHOOL
# 362. SUSAN E. WAGNER HIGH SCHOOL
# 363. CONCORD HIGH SCHOOL
# 364. RALPH R. MCKEE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL
# 365. YOUNG ADULT BOROUGH CENTER AT STATEN IS TECH HS
# 366. ACADEMY FOR ENVIRONMENTAL LEADERSHIP
# 367. EBC HIGH SCHOOL FOR PUBLIC SERVICE–BUSHWICK
# 368. BUSHWICK SCHOOL FOR SOCIAL JUSTICE
# 369. ACADEMY OF URBAN PLANNING
# 370. ALL CITY LEADERSHIP SECONDARY SCHOOL
# 371. BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCELLENCE
# 372. BUSHWICK COMMUNITY HIGH SCHOOL
# 373. P.S. Q811
# 374. PHOENIX ACADEMY
#
# Cluster 1:
# 1. NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND MATH HIGH SCHOOL
# 2. N.Y.C. LAB SCHOOL FOR COLLABORATIVE STUDIES
# 3. SCHOOL OF THE FUTURE HIGH SCHOOL
# 4. MILLENNIUM HIGH SCHOOL
# 5. URBAN ACADEMY LABORATORY HIGH SCHOOL
# 6. LEON M. GOLDSTEIN HIGH SCHOOL FOR THE SCIENCES
# 7. BARD HIGH SCHOOL EARLY COLLEGE II
# 8. SCHOLARS' ACADEMY
# 9. QUEENS GATEWAY TO HEALTH SCIENCES SECONDARY SCHOOL
# 10. BACCALAUREATE SCHOOL FOR GLOBAL EDUCATION
#
# Cluster 2:
# 1. INTERNATIONAL COMMUNITY HIGH SCHOOL
# 2. ACADEMY FOR LANGUAGE AND TECHNOLOGY
# 3. BRONX INTERNATIONAL HIGH SCHOOL
# 4. KINGSBRIDGE INTERNATIONAL HIGH SCHOOL
# 5. INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# 6. PAN AMERICAN INTERNATIONAL HIGH SCHOOL AT MONROE
# 7. HIGH SCHOOL OF WORLD CULTURES
# 8. BROOKLYN INTERNATIONAL HIGH SCHOOL
# 9. INTERNATIONAL HIGH SCHOOL AT PROSPECT HEIGHTS
# 10. IT TAKES A VILLAGE ACADEMY
# 11. MULTICULTURAL HIGH SCHOOL
# 12. ASPIRATIONS DIPLOMA PLUS HIGH SCHOOL
# 13. PAN AMERICAN INTERNATIONAL HIGH SCHOOL

# %%
# Convert columns to numeric for calculations
for col in ['SAT Critical Reading Avg. Score', 'SAT Math Avg. Score', 'SAT Writing Avg. Score']:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Group by DBSCAN clusters and calculate average scores
for col in ['SAT Critical Reading Avg. Score', 'SAT Math Avg. Score', 'SAT Writing Avg. Score']:
    cluster_avg_db = data.groupby('Cluster_DBSCAN')[col].mean()

    # Plot pie chart for average scores based on DBSCAN clusters
    plt.figure(figsize=(8, 6))
    plt.pie(cluster_avg_db, labels=cluster_avg_db.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'Average {col} by DBSCAN Cluster')
    plt.show()

# %%
# Convert 'Num of SAT Test Takers' column to numeric
data['Num of SAT Test Takers'] = pd.to_numeric(data['Num of SAT Test Takers'], errors='coerce')

# Average Num of SAT Test Takers for every cluster
cluster_avg_num_test_takers = data.groupby('Cluster_DBSCAN')['Num of SAT Test Takers'].mean()

# Create a bar plot
plt.figure(figsize=(8, 6))
barplot = sns.barplot(x=cluster_avg_num_test_takers.index, y=cluster_avg_num_test_takers.values, palette='viridis')
plt.title('Average Num of SAT Test Takers for Every Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Num of SAT Test Takers')

# Annotate bars with the final number of test takers
for i, num_test_takers in enumerate(cluster_avg_num_test_takers):
    barplot.text(i, num_test_takers + 5, f'{num_test_takers:.2f}', ha='center', fontsize=10)

plt.show()
# Out:
# C:\Users\stavros\AppData\Local\Temp\ipykernel_14456\412424647.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=cluster_avg_num_test_takers.index, y=cluster_avg_num_test_takers.values, palette='viridis')

# %% [markdown]
# **Because from Kmeans the best Cluster is cluster 2 where it has less students than any other class and the results of the tests are better than the others. In the DBSCAN the -1 cluster had better results and had more students than the others. So we find the intersection of these two clusters in order to see which schools are the best for funding opportunities.**

# %%
cluster_num = 2 # Get the school names in the cluster with label 2 
cluster_schools_cluster = set(data[data['Cluster'] == cluster_num]['SCHOOL NAME'])

cluster_num_dbscan = -1 # Get the school names in the cluster with label -1
cluster_schools_dbscan = set(data[data['Cluster_DBSCAN'] == cluster_num_dbscan]['SCHOOL NAME'])

# Iintersection of school names between the two clusters
intersection_schools = cluster_schools_cluster.intersection(cluster_schools_dbscan)

# Print the school names in the intersection
print('The schools that deserve fundings')
print(f"School names in the intersection of Cluster {cluster_num} and Cluster {cluster_num_dbscan}:")
for i, school in enumerate(intersection_schools, start=1):
    print(f"{i}. {school}")
# Out:
# The schools that deserve fundings
# School names in the intersection of Cluster 2 and Cluster -1:
# 1. QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK COLLEGE
# 2. STATEN ISLAND TECHNICAL HIGH SCHOOL
# 3. BROOKLYN LATIN SCHOOL, THE
# 4. HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE
# 5. FIORELLO H. LAGUARDIA HIGH SCHOOL OF MUSIC & ART AND PERFORMING ARTS
# 6. BROOKLYN TECHNICAL HIGH SCHOOL
# 7. BEACON HIGH SCHOOL
# 8. HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGINEERING AT CITY COLLEGE
# 9. TOWNSEND HARRIS HIGH SCHOOL
# 10. BARUCH COLLEGE CAMPUS HIGH SCHOOL
# 11. ELEANOR ROOSEVELT HIGH SCHOOL
# 12. BRONX HIGH SCHOOL OF SCIENCE
# 13. STUYVESANT HIGH SCHOOL
# 14. BARD HIGH SCHOOL EARLY COLLEGE
